# %%
#aks user for input
a= float(input("enter a:"))
b= float(input("enter b:"))
c= float(input("enter c:"))

#calculate D
D = (b**2)-4*a*c

if D>0:
    x_1=(-b +D**0.5)/(2*a) 
    x_2=(-b +D**0.5)/(2*a)
    print(f"x_1={x_1}, x_2={x_2}")

elif D==0:
 x=-b/(2*a)
 print (f"x=+ {x}")
        
else:
    print("D<0")
